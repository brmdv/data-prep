# %% [markdown]
# # Data preprocessing: NYC Crashes
#
# In this project, a dataset with information about car crashes in New York is cleaned and preprocessed for Machine Learning.
#
# Let us begin with importing Pandas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import the (test) data as a Pandas dataframe and take a first look.

# %%
df = pd.read_csv('data_100000.csv')
df.head()
# Out:
#                 crash_date crash_time        borough  zip_code   latitude  \
# 0  2017-04-18T00:00:00.000      23:10  STATEN ISLAND   10312.0  40.536728
# 1  2017-05-06T00:00:00.000      13:00          BRONX   10472.0  40.829052
# 2  2017-04-27T00:00:00.000      17:15         QUEENS   11420.0  40.677303
# 3  2017-05-09T00:00:00.000      20:10            NaN       NaN  40.624958
# 4  2017-04-18T00:00:00.000      14:00          BRONX   10456.0  40.828846
#
#    longitude                 location                    on_street_name  \
# 0 -74.193344  (40.536728, -74.193344)                               NaN
# 1 -73.850380   (40.829052, -73.85038)  CASTLE HILL AVENUE
# 2 -73.804565  (40.677303, -73.804565)  135 STREET
# 3 -74.145775  (40.624958, -74.145775)  FOREST AVENUE
# 4 -73.903120   (40.828846, -73.90312)                               NaN
#
#     off_street_name                         cross_street_name  ...  \
# 0               NaN  243       DARLINGTON AVENUE               ...
# 1  BLACKROCK AVENUE                                       NaN  ...
# 2    FOCH BOULEVARD                                       NaN  ...
# 3   RICHMOND AVENUE                                       NaN  ...
# 4               NaN  1167      BOSTON ROAD                     ...
#
#    contributing_factor_vehicle_2  contributing_factor_vehicle_3  \
# 0                    Unspecified                            NaN
# 1                            NaN                            NaN
# 2                    Unspecified                            NaN
# 3                    Unspecified                    Unspecified
# 4                    Unspecified                            NaN
#
#    contributing_factor_vehicle_4  contributing_factor_vehicle_5  collision_id  \
# 0                            NaN                            NaN       3654181
# 1                            NaN                            NaN       3665311
# 2                            NaN                            NaN       3658491
# 3                            NaN                            NaN       3666554
# 4                            NaN                            NaN       3653269
#
#                     vehicle_type_code1                   vehicle_type_code2  \
# 0  Station Wagon/Sport Utility Vehicle                                  NaN
# 1                                Sedan                                  NaN
# 2                                Sedan                                Sedan
# 3                           Motorcycle                                Sedan
# 4                                Sedan  Station Wagon/Sport Utility Vehicle
#
#    vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  Bus                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_date                     100000 non-null  object
#  1   crash_time                     100000 non-null  object
#  2   borough                        64974 non-null   object
#  3   zip_code                       64966 non-null   float64
#  4   latitude                       91965 non-null   float64
#  5   longitude                      91965 non-null   float64
#  6   location                       91965 non-null   object
#  7   on_street_name                 73991 non-null   object
#  8   off_street_name                47125 non-null   object
#  9   cross_street_name              25967 non-null   object
#  10  number_of_persons_injured      100000 non-null  int64
#  11  number_of_persons_killed       100000 non-null  int64
#  12  number_of_pedestrians_injured  100000 non-null  int64
#  13  number_of_pedestrians_killed   100000 non-null  int64
#  14  number_of_cyclist_injured      100000 non-null  int64
#  15  number_of_cyclist_killed       100000 non-null  int64
#  16  number_of_motorist_injured     100000 non-null  int64
#  17  number_of_motorist_killed      100000 non-null  int64
#  18  contributing_factor_vehicle_1  99629 non-null   object
#  19  contributing_factor_vehicle_2  80757 non-null   object
#  20  contributing_factor_vehicle_3  8761 non-null    object
#  21  contributing_factor_vehicle_4  2240 non-null    object
#  22  contributing_factor_vehicle_5  667 non-null     object
#  23  collision_id                   100000 non-null  int64
#  24  vehicle_type_code1             99260 non-null   object
#  25  vehicle_type_code2             73411 non-null   object
#  26  vehicle_type_code_3            8329 non-null    object
#  27  vehicle_type_code_4            2147 non-null    object
#  28  vehicle_type_code_5            646 non-null     object
# dtypes: float64(3), int64(9), object(17)
# memory usage: 22.1+ MB

# %% [markdown]
# There are a lot of null values and it is tempting to remove them. But in order to get a better understanding for which data is important, redundant, double, I will first clean it up a bit. We candon't want to throw away data if it's not necessary.

# %% [markdown]
# ## Data types
# Let us begin checking that every feature has the correct dtype.
#
# To start, the **date and time** are just strings now. We could fix that when importing creating the dataframe, so let's do that now there's still the chance.

# %%
# reimport the data
df = pd.read_csv('data_1000.csv', parse_dates=[[0,1]])
df.rename(columns={'crash_date_crash_time': "crash_datetime"}, inplace=True)  # simplify column name
df.head()
# Out:
#        crash_datetime        borough  zip_code   latitude  longitude  \
# 0 2017-04-18 23:10:00  STATEN ISLAND   10312.0  40.536728 -74.193344
# 1 2017-05-06 13:00:00          BRONX   10472.0  40.829052 -73.850380
# 2 2017-04-27 17:15:00         QUEENS   11420.0  40.677303 -73.804565
# 3 2017-05-09 20:10:00            NaN       NaN  40.624958 -74.145775
# 4 2017-04-18 14:00:00          BRONX   10456.0  40.828846 -73.903120
#
#                   location                    on_street_name  \
# 0  (40.536728, -74.193344)                               NaN
# 1   (40.829052, -73.85038)  CASTLE HILL AVENUE
# 2  (40.677303, -73.804565)  135 STREET
# 3  (40.624958, -74.145775)  FOREST AVENUE
# 4   (40.828846, -73.90312)                               NaN
#
#     off_street_name                         cross_street_name  \
# 0               NaN  243       DARLINGTON AVENUE
# 1  BLACKROCK AVENUE                                       NaN
# 2    FOCH BOULEVARD                                       NaN
# 3   RICHMOND AVENUE                                       NaN
# 4               NaN  1167      BOSTON ROAD
#
#    number_of_persons_injured  ...  contributing_factor_vehicle_2  \
# 0                          0  ...                    Unspecified
# 1                          1  ...                            NaN
# 2                          0  ...                    Unspecified
# 3                          1  ...                    Unspecified
# 4                          0  ...                    Unspecified
#
#    contributing_factor_vehicle_3  contributing_factor_vehicle_4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                    Unspecified                            NaN
# 4                            NaN                            NaN
#
#    contributing_factor_vehicle_5  collision_id  \
# 0                            NaN       3654181
# 1                            NaN       3665311
# 2                            NaN       3658491
# 3                            NaN       3666554
# 4                            NaN       3653269
#
#                     vehicle_type_code1                   vehicle_type_code2  \
# 0  Station Wagon/Sport Utility Vehicle                                  NaN
# 1                                Sedan                                  NaN
# 2                                Sedan                                Sedan
# 3                           Motorcycle                                Sedan
# 4                                Sedan  Station Wagon/Sport Utility Vehicle
#
#   vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 Bus                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# Another very obvious thing is that the `zip_code` is interpreted as a float in stead of an int. [Apparently](https://pandas.pydata.org/pandas-docs/stable/user_guide/gotchas.html#support-for-integer-na) Numpy doesn't support nullable integers or something like that, so we have to use a special Pandas type `pd.Int##Dtype()` for this. Another option would be storing the zip codes as strings.

# %%
df["zip_code"]=df["zip_code"].astype(pd.UInt16Dtype())
df.head()
# Out:
#        crash_datetime        borough  zip_code   latitude  longitude  \
# 0 2017-04-18 23:10:00  STATEN ISLAND     10312  40.536728 -74.193344
# 1 2017-05-06 13:00:00          BRONX     10472  40.829052 -73.850380
# 2 2017-04-27 17:15:00         QUEENS     11420  40.677303 -73.804565
# 3 2017-05-09 20:10:00            NaN      <NA>  40.624958 -74.145775
# 4 2017-04-18 14:00:00          BRONX     10456  40.828846 -73.903120
#
#                   location                    on_street_name  \
# 0  (40.536728, -74.193344)                               NaN
# 1   (40.829052, -73.85038)  CASTLE HILL AVENUE
# 2  (40.677303, -73.804565)  135 STREET
# 3  (40.624958, -74.145775)  FOREST AVENUE
# 4   (40.828846, -73.90312)                               NaN
#
#     off_street_name                         cross_street_name  \
# 0               NaN  243       DARLINGTON AVENUE
# 1  BLACKROCK AVENUE                                       NaN
# 2    FOCH BOULEVARD                                       NaN
# 3   RICHMOND AVENUE                                       NaN
# 4               NaN  1167      BOSTON ROAD
#
#    number_of_persons_injured  ...  contributing_factor_vehicle_2  \
# 0                          0  ...                    Unspecified
# 1                          1  ...                            NaN
# 2                          0  ...                    Unspecified
# 3                          1  ...                    Unspecified
# 4                          0  ...                    Unspecified
#
#    contributing_factor_vehicle_3  contributing_factor_vehicle_4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                    Unspecified                            NaN
# 4                            NaN                            NaN
#
#    contributing_factor_vehicle_5  collision_id  \
# 0                            NaN       3654181
# 1                            NaN       3665311
# 2                            NaN       3658491
# 3                            NaN       3666554
# 4                            NaN       3653269
#
#                     vehicle_type_code1                   vehicle_type_code2  \
# 0  Station Wagon/Sport Utility Vehicle                                  NaN
# 1                                Sedan                                  NaN
# 2                                Sedan                                Sedan
# 3                           Motorcycle                                Sedan
# 4                                Sedan  Station Wagon/Sport Utility Vehicle
#
#   vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 Bus                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Duplicates
#
# `longitude` and `latitude` are also kept as object in `location`. Before dropping location, let us quickly check if they are always equal.

# %%
# create series with location strings
fake_location=df.apply(lambda x: f"({x['latitude']}, {x['longitude']})", axis=1)

# filter all rows where they are not equal
df[df['location']!=fake_location]
# Out:
#                     crash_date crash_time        borough  zip_code  latitude  \
# 24     2018-02-17T00:00:00.000      14:30      MANHATTAN   10019.0       NaN
# 25     2019-12-04T00:00:00.000      15:30  STATEN ISLAND   10309.0       NaN
# 26     2017-09-12T00:00:00.000      17:59            NaN       NaN       NaN
# 27     2017-05-07T00:00:00.000      15:00            NaN       NaN       NaN
# 36     2017-04-25T00:00:00.000      19:30            NaN       NaN       NaN
# ...                        ...        ...            ...       ...       ...
# 99935  2019-11-21T00:00:00.000      17:00            NaN       NaN       NaN
# 99944  2019-11-15T00:00:00.000      13:52         QUEENS   11373.0       NaN
# 99965  2020-03-04T00:00:00.000      23:47            NaN       NaN       NaN
# 99982  2019-11-07T00:00:00.000      17:08            NaN       NaN       NaN
# 99990  2019-11-08T00:00:00.000      19:20       BROOKLYN   11218.0       NaN
#
#        longitude location                    on_street_name   off_street_name  \
# 24           NaN      NaN                               NaN               NaN
# 25           NaN      NaN                               NaN               NaN
# 26           NaN      NaN  PARK ROW                                       NaN
# 27           NaN      NaN  CENTER BOULEVARD                               NaN
# 36           NaN      NaN  THROGS NECK EXPRESSWAY              HARDING AVENUE
# ...          ...      ...                               ...               ...
# 99935        NaN      NaN  CROSS ISLAND PARKWAY                    149 STREET
# 99944        NaN      NaN  HORACE HARDING EXPRESSWAY         QUEENS BOULEVARD
# 99965        NaN      NaN  WAKEFIELD AVENUE                    BULLARD AVENUE
# 99982        NaN      NaN  BRONX WHITESTONE BRIDGE                        NaN
# 99990        NaN      NaN  OCEAN PARKWAY                             AVENUE C
#
#                               cross_street_name  ...  \
# 24     450       W 57th St                       ...
# 25     715       sharrotts rd                    ...
# 26                                          NaN  ...
# 27                                          NaN  ...
# 36                                          NaN  ...
# ...                                         ...  ...
# 99935                                       NaN  ...
# 99944                                       NaN  ...
# 99965                                       NaN  ...
# 99982                                       NaN  ...
# 99990                                       NaN  ...
#
#         contributing_factor_vehicle_2  contributing_factor_vehicle_3  \
# 24                        Unspecified                            NaN
# 25                                NaN                            NaN
# 26                                NaN                            NaN
# 27                                NaN                            NaN
# 36                        Unspecified                            NaN
# ...                               ...                            ...
# 99935                     Unspecified                            NaN
# 99944  Driver Inattention/Distraction                            NaN
# 99965                     Unspecified                    Unspecified
# 99982                     Unspecified                            NaN
# 99990                     Unspecified                            NaN
#
#        contributing_factor_vehicle_4  contributing_factor_vehicle_5  \
# 24                               NaN                            NaN
# 25                               NaN                            NaN
# 26                               NaN                            NaN
# 27                               NaN                            NaN
# 36                               NaN                            NaN
# ...                              ...                            ...
# 99935                            NaN                            NaN
# 99944                            NaN                            NaN
# 99965                            NaN                            NaN
# 99982                            NaN                            NaN
# 99990                            NaN                            NaN
#
#        collision_id                   vehicle_type_code1  vehicle_type_code2  \
# 24          3848714                                Sedan               Sedan
# 25          4263561                 Tractor Truck Diesel                 NaN
# 26          3749038                                  Bus                 NaN
# 27          3668217  Station Wagon/Sport Utility Vehicle                 NaN
# 36          3658008                                Sedan               Sedan
# ...             ...                                  ...                 ...
# 99935       4245413                                Sedan                 NaN
# 99944       4241598  Station Wagon/Sport Utility Vehicle           Box Truck
# 99965       4297737                                Sedan       Pick-up Truck
# 99982       4237898  Station Wagon/Sport Utility Vehicle               Sedan
# 99990       4238828                                Sedan               Sedan
#
#        vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5
# 24                     NaN                 NaN                 NaN
# 25                     NaN                 NaN                 NaN
# 26                     NaN                 NaN                 NaN
# 27                     NaN                 NaN                 NaN
# 36                     NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 99935                  NaN                 NaN                 NaN
# 99944                  NaN                 NaN                 NaN
# 99965                Sedan                 NaN                 NaN
# 99982                  NaN                 NaN                 NaN
# 99990                  NaN                 NaN                 NaN
#
# [8035 rows x 29 columns]

# %% [markdown]
# Only the NaN locations are not equal, so we can safely drop **location**.

# %%
df.drop(["location"], axis=1,inplace=True)
df.head()
# Out:
#                 crash_date crash_time        borough  zip_code   latitude  \
# 0  2017-04-18T00:00:00.000      23:10  STATEN ISLAND   10312.0  40.536728
# 1  2017-05-06T00:00:00.000      13:00          BRONX   10472.0  40.829052
# 2  2017-04-27T00:00:00.000      17:15         QUEENS   11420.0  40.677303
# 3  2017-05-09T00:00:00.000      20:10            NaN       NaN  40.624958
# 4  2017-04-18T00:00:00.000      14:00          BRONX   10456.0  40.828846
#
#    longitude                    on_street_name   off_street_name  \
# 0 -74.193344                               NaN               NaN
# 1 -73.850380  CASTLE HILL AVENUE                BLACKROCK AVENUE
# 2 -73.804565  135 STREET                          FOCH BOULEVARD
# 3 -74.145775  FOREST AVENUE                      RICHMOND AVENUE
# 4 -73.903120                               NaN               NaN
#
#                           cross_street_name  number_of_persons_injured  ...  \
# 0  243       DARLINGTON AVENUE                                       0  ...
# 1                                       NaN                          1  ...
# 2                                       NaN                          0  ...
# 3                                       NaN                          1  ...
# 4  1167      BOSTON ROAD                                             0  ...
#
#    contributing_factor_vehicle_2  contributing_factor_vehicle_3  \
# 0                    Unspecified                            NaN
# 1                            NaN                            NaN
# 2                    Unspecified                            NaN
# 3                    Unspecified                    Unspecified
# 4                    Unspecified                            NaN
#
#    contributing_factor_vehicle_4  contributing_factor_vehicle_5  collision_id  \
# 0                            NaN                            NaN       3654181
# 1                            NaN                            NaN       3665311
# 2                            NaN                            NaN       3658491
# 3                            NaN                            NaN       3666554
# 4                            NaN                            NaN       3653269
#
#                     vehicle_type_code1                   vehicle_type_code2  \
# 0  Station Wagon/Sport Utility Vehicle                                  NaN
# 1                                Sedan                                  NaN
# 2                                Sedan                                Sedan
# 3                           Motorcycle                                Sedan
# 4                                Sedan  Station Wagon/Sport Utility Vehicle
#
#   vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 Bus                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
# [5 rows x 28 columns]
